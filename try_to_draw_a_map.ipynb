# %%
# !pip install git+https://github.com/abey79/vsketch#egg=vsketch
# !pip install git+https://github.com/marceloprates/prettymaps.git

# !mkdir ../prints
# !mkdir ../assets
# !mkdir ../assets/Permanent_Marker/
# !wget -O ../assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# Collecting vsketch
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vsketch 'C:\Users\Justin\AppData\Local\Temp\pip-install-2zakwjnc\vsketch_a74e81833bf34fbaae274d9a7bb01034'
#   Cloning https://github.com/abey79/vsketch to c:\users\justin\appdata\local\temp\pip-install-2zakwjnc\vsketch_a74e81833bf34fbaae274d9a7bb01034
#   Resolved https://github.com/abey79/vsketch to commit 495c8c8a01a22e7536d8da9eae39e03fa8b94950
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee
#   Using cached vpype-1.11.0a0-py3-none-any.whl
# Requirement already satisfied: Shapely[vectorized]==1.8.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (1.8.2)
# Requirement already satisfied: cookiecutter>=2.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (2.1.1)
# Requirement already satisfied: qasync>=0.22 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (0.23.0)
# Requirement already satisfied: numpy>=1.20.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (1.23.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (3.5.2)
# Requirement already satisfied: pnoise>=0.2.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (0.2.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.4 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (0.4.5)
# Requirement already satisfied: PySide2<6.0.0,>=5.15.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (5.15.2.1)
# Requirement already satisfied: watchfiles>=0.12 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (0.16.0)
# Requirement already satisfied: multiprocess>=0.70 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vsketch) (0.70.13)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (8.1.3)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (6.1.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (2.28.1)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (0.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (3.1.2)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from cookiecutter>=2.1->vsketch) (0.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (21.3)
# Requirement already satisfied: dill>=0.3.5.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from multiprocess>=0.70->vsketch) (0.3.5.1)
# Requirement already satisfied: shiboken2==5.15.2.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from PySide2<6.0.0,>=5.15.2->vsketch) (5.15.2.1)
# Requirement already satisfied: anyio<4,>=3.0.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from watchfiles>=0.12->vsketch) (3.6.1)
# Requirement already satisfied: asteval>=0.9.26 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (0.9.27)
# Requirement already satisfied: tomli>=2.0.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (2.0.1)
# Requirement already satisfied: scipy>=1.6 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (1.8.1)
# Requirement already satisfied: svgelements>=1.6.10 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (1.7.2)
# Requirement already satisfied: cachetools>=4.2.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (5.2.0)
# Requirement already satisfied: svgwrite<1.5,>=1.4 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (1.4.3)
# Requirement already satisfied: moderngl>=5.6.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (5.6.4)
# Requirement already satisfied: glcontext>=2.3.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from vpype[all]@ git+https://github.com/abey79/vpype@6a099b7b4f3d756f7fa8052049be365d0314c5ee->vsketch) (2.3.6)
# Requirement already satisfied: idna>=2.8 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from anyio<4,>=3.0.0->watchfiles>=0.12->vsketch) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from anyio<4,>=3.0.0->watchfiles>=0.12->vsketch) (1.2.0)
# Requirement already satisfied: chardet>=3.0.2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from binaryornot>=0.4.4->cookiecutter>=2.1->vsketch) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=2.1->vsketch) (2.1.1)
# Requirement already satisfied: arrow in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter>=2.1->vsketch) (1.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.3.3->vsketch) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from python-slugify>=4.0.0->cookiecutter>=2.1->vsketch) (1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch) (2022.6.15)
# Collecting git+https://github.com/marceloprates/prettymaps.git
#   Running command git clone --filter=blob:none --quiet https://github.com/marceloprates/prettymaps.git 'C:\Users\Justin\AppData\Local\Temp\pip-req-build-pbj2zcun'
#   warning: the following paths have collided (e.g. case-sensitive paths
#   on a case-insensitive filesystem) and only one from the same
#   colliding group is in the working tree:
#
#     'prints/Erbil.svg'
#     'prints/erbil.svg'
#     'prints/Palmanova.svg'
#     'prints/palmanova.svg'
#   Cloning https://github.com/marceloprates/prettymaps.git to c:\users\justin\appdata\local\temp\pip-req-build-pbj2zcun
#   Resolved https://github.com/marceloprates/prettymaps.git to commit 72fd33ce5f075020ea272e80df906c64c53d4d93
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: osmnx==1.0.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from prettymaps==0.1.3) (1.0.1)
# Requirement already satisfied: tabulate==0.8.9 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from prettymaps==0.1.3) (0.8.9)
# Requirement already satisfied: requests>=2.25 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.28.1)
# Requirement already satisfied: geopandas>=0.8 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (0.11.0)
# Requirement already satisfied: networkx>=2.5 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.8.5)
# Requirement already satisfied: descartes>=1.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.1.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.23.1)
# Requirement already satisfied: pandas>=1.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.4.3)
# Requirement already satisfied: Shapely>=1.7 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.8.2)
# Requirement already satisfied: pyproj>=2.6 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.3.1)
# Requirement already satisfied: Rtree>=0.9 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.0.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.5.2)
# Requirement already satisfied: packaging in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (21.3)
# Requirement already satisfied: fiona>=1.8 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.8.21)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps==0.1.3) (2022.1)
# Requirement already satisfied: certifi in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from pyproj>=2.6->osmnx==1.0.1->prettymaps==0.1.3) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (3.3)
# Requirement already satisfied: attrs>=17 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (21.4.0)
# Requirement already satisfied: click>=4.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.16.0)
# Requirement already satisfied: munch in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (63.2.0)
# Requirement already satisfied: colorama in c:\users\justin\anaconda3\envs\prettymaps\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (0.4.5)
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# For local execution (does not require installing the library):
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('../')

# Prettymaps
from prettymaps import *
# Vsketch
import vsketch
# OSMNX
import osmnx as ox
# Matplotlib-related
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt
from descartes import PolygonPatch
# Shapely
from shapely.geometry import *
from shapely.affinity import *
from shapely.ops import unary_union

# %%
# ANNAS LONG AND LAT
center = [42.753046, -84.504777]

# %%
# fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)
# layers = plot(

# (31.23346, 121.492154), # The coordinates of the center of the circle , Format ：( latitude , longitude )

# radius = 2500, # radius 

# ax = ax, # Binding drawing bed 

# layers = {

# 'perimeter': {}, # Controls the drawing mode ,{} That is, it is equivalent to circular drawing mode 

# # The following parameters are used to define from OsmStreetMap Select the acquired vector layer features , If you don't understand it, you can copy it without change 

# 'streets': {



# 'width': {

# 'motorway': 5,

# 'trunk': 5,

# 'primary': 4.5,

# 'secondary': 4,

# 'tertiary': 3.5,

# 'residential': 3,

# 'service': 2,

# 'unclassified': 2,

# 'pedestrian': 2,

# 'footway': 1,

# }

# },

# 'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},

# 'water': {'tags': {'natural': ['water', 'bay']}},

# 'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},

# 'forest': {'tags': {'landuse': 'forest'}},

# 'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}

# },

# # The following parameters are used to define OpenStreetMap Styles of different vector layers in , If you feel troublesome, just copy the following official example 

# drawing_kwargs = {

# 'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},

# 'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...', 'zorder': 0},

# 'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},

# 'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},

# 'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},

# 'parking': {'fc': '#F2F4CB', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},

# 'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},

# 'building': {'palette': ['#FFC857', '#E9724C', '#C5283D'], 'ec': '#2F3737', 'lw': .5, 'zorder': 4},

# },
# osm_credit = {'color': '#2F3737'}

# )
# # Export picture file 

# plt.savefig(' Shanghai Bund - Circular pattern .png', dpi=500)

# %%
###################

fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

layers = plot(
    (42.753046, -84.504777), radius = 1100,
    ax = ax,
    layers = {
            'perimeter': {},
            'streets': {
                'custom_filter': '["highway"~"motorway|trunk|primary|secondary|tertiary|residential|service|unclassified|pedestrian|footway"]',
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                }
            },
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
            'water': {'tags': {'natural': ['water', 'bay']}},
            'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
            'forest': {'tags': {'landuse': 'forest'}},
            'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
        },
        drawing_kwargs = {
            'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
            'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...',  'zorder': 0},
            'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
            'parking': {'fc': '#F2F4CB', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
            'building': {'palette': ['#FFC857', '#E9724C', '#C5283D'], 'ec': '#2F3737', 'lw': .5, 'zorder': 4},
        },

        osm_credit = {'color': '#2F3737'}
)

plt.savefig('../prints/macao.png')
#plt.savefig('../prints/macao.svg')
# Out:
# c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\osmnx\utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\osmnx\utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\osmnx\utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Justin\Desktop\Project\Maps\Untitled.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> ###################
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> layers = plot(
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     (42.753046, -84.504777), radius = 1100,
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     ax = ax,
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     layers = {
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>             'perimeter': {},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>             'streets': {
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>                 'custom_filter': '["highway"~"motorway|trunk|primary|secondary|tertiary|residential|service|unclassified|pedestrian|footway"]',
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>                 'width': {
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>                     'motorway': 5,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>                     'trunk': 5,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>                     'primary': 4.5,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>                     'secondary': 4,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>                     'tertiary': 3.5,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>                     'residential': 3,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>                     'service': 2,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>                     'unclassified': 2,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>                     'pedestrian': 2,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>                     'footway': 1,
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>                 }
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a>             },
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=24'>25</a>             'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=25'>26</a>             'water': {'tags': {'natural': ['water', 'bay']}},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a>             'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a>             'forest': {'tags': {'landuse': 'forest'}},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a>             'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=29'>30</a>         },
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a>         drawing_kwargs = {
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a>             'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=32'>33</a>             'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...',  'zorder': 0},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a>             'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=34'>35</a>             'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a>             'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a>             'parking': {'fc': '#F2F4CB', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>             'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=38'>39</a>             'building': {'palette': ['#FFC857', '#E9724C', '#C5283D'], 'ec': '#2F3737', 'lw': .5, 'zorder': 4},
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a>         },
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=40'>41</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a>         osm_credit = {'color': '#2F3737'}
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=42'>43</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/Desktop/Project/Maps/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=44'>45</a> plt.savefig('../prints/macao.png')
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\prettymaps\draw.py:230, in plot(query, backup, postprocessing, radius, layers, drawing_kwargs, osm_credit, figsize, ax, title, vsketch, x, y, scale_x, scale_y, rotation)
#     223     base_kwargs = {
#     224         "perimeter": query
#     225         if query_mode == "polygon"
#     226         else get_perimeter(query, by_osmid=query_mode == "osmid")
#     227     }
#     229 # Fetch layers
# --> 230 layers = {
#     231     layer: get_layer(
#     232         layer, **base_kwargs, **(kwargs if type(kwargs) == dict else {})
#     233     )
#     234     for layer, kwargs in layers.items()
#     235 }
#     237 # Apply transformation to layers (translate & scale)
#     238 layers = transform(layers, x, y, scale_x, scale_y, rotation)
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\prettymaps\draw.py:231, in <dictcomp>(.0)
#     223     base_kwargs = {
#     224         "perimeter": query
#     225         if query_mode == "polygon"
#     226         else get_perimeter(query, by_osmid=query_mode == "osmid")
#     227     }
#     229 # Fetch layers
#     230 layers = {
# --> 231     layer: get_layer(
#     232         layer, **base_kwargs, **(kwargs if type(kwargs) == dict else {})
#     233     )
#     234     for layer, kwargs in layers.items()
#     235 }
#     237 # Apply transformation to layers (translate & scale)
#     238 layers = transform(layers, x, y, scale_x, scale_y, rotation)
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\prettymaps\fetch.py:380, in get_layer(layer, **kwargs)
#     378 # Fetch streets or railway
#     379 if layer in ["streets", "railway", "waterway"]:
# --> 380     return get_streets(**kwargs, layer=layer)
#     381 # Fetch Coastline
#     382 elif layer == "coastline":
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\prettymaps\fetch.py:293, in get_streets(perimeter, point, radius, layer, width, custom_filter, buffer, retain_all, circle, dilate, truncate_by_edge)
#     285 streets = ox.graph_from_point(
#     286     point,
#     287     dist=radius + dilate + buffer,
#    (...)
#     290     truncate_by_edge = truncate_by_edge,
#     291 )
#     292 crs = ox.graph_to_gdfs(streets, nodes=False).crs
# --> 293 streets = ox.project_graph(streets)
#     294 # Compute perimeter from point & CRS
#     295 perimeter = get_boundary(point, radius, crs, circle=circle, dilate=dilate)
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\osmnx\projection.py:144, in project_graph(G, to_crs)
#     141 if "simplified" in G.graph and G.graph["simplified"]:
#     142     # if graph has previously been simplified, project the edge geometries
#     143     gdf_edges = utils_graph.graph_to_gdfs(G, nodes=False, fill_edge_geometry=True)
# --> 144     gdf_edges_proj = project_gdf(gdf_edges, to_crs=gdf_nodes_proj.crs)
#     145 else:
#     146     # if not, you don't have to project these edges because the nodes
#     147     # contain all the spatial data in the graph (unsimplified edges have
#     148     # no geometry attributes)
#     149     gdf_edges_proj = utils_graph.graph_to_gdfs(G, nodes=False, fill_edge_geometry=False).drop(
#     150         columns=["geometry"]
#     151     )
#
# File c:\Users\Justin\anaconda3\envs\PrettyMaps\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'crs'
